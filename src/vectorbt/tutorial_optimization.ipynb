# %%
import pandas as pd
import numpy as np
from src.utils import reload_module

# %%
OptimizedMa = reload_module("strategies/optimized_ma", "OptimizedMa")

PAIRS = ["BTC", "ETH"]

o = OptimizedMa("USD", PAIRS, "temp_data.json")
o.get_data(3, "1m")
o.create_indicator()
pf = o.run(
    rsi_window=np.arange(10, 50, step=5, dtype=int),
    rsi_period=["5T", "10T"],
    ma_window=np.arange(20, 100, step=10, dtype=int),
    entry_threshold=np.arange(30, 40, step=2, dtype=int),
    exit_threshold=np.arange(60, 70, step=2, dtype=int),
)
# Out:
# Using data from temp_data.json

# %%
pf.trades.close
# Out:
# comb_rsi_window                 10
# comb_rsi_period                 5T
# comb_ma_window                  20
# comb_entry_threshold            30
# comb_exit_threshold             60                         62
#                            BTC-USD      ETH-USD       BTC-USD      ETH-USD
# 2024-01-03 13:29:00   42528.835938  2224.429199  42528.835938  2224.429199  \
# 2024-01-03 13:30:00   42564.808594  2225.953125  42564.808594  2225.953125
# 2024-01-03 13:31:00   42565.449219  2228.655273  42565.449219  2228.655273
# 2024-01-03 13:32:00   42506.980469  2224.570557  42506.980469  2224.570557
# 2024-01-03 13:33:00   42496.070312  2223.193115  42496.070312  2223.193115
# ..                             ...          ...           ...          ...
# 2024-01-06 13:21:00   43698.253906  2237.023926  43698.253906  2237.023926
# 2024-01-06 13:22:00   43698.457031  2236.943115  43698.457031  2236.943115
# 2024-01-06 13:23:00   43693.328125  2236.354248  43693.328125  2236.354248
# 2024-01-06 13:24:00   43705.101562  2236.707031  43705.101562  2236.707031
# 2024-01-06 13:25:00   43707.925781  2237.018799  43707.925781  2237.018799
#
# comb_rsi_window
# comb_rsi_period
# comb_ma_window
# comb_entry_threshold
# comb_exit_threshold             64                         66
#                            BTC-USD      ETH-USD       BTC-USD      ETH-USD
# 2024-01-03 13:29:00   42528.835938  2224.429199  42528.835938  2224.429199  \
# 2024-01-03 13:30:00   42564.808594  2225.953125  42564.808594  2225.953125
# 2024-01-03 13:31:00   42565.449219  2228.655273  42565.449219  2228.655273
# 2024-01-03 13:32:00   42506.980469  2224.570557  42506.980469  2224.570557
# 2024-01-03 13:33:00   42496.070312  2223.193115  42496.070312  2223.193115
# ..                             ...          ...           ...          ...
# 2024-01-06 13:21:00   43698.253906  2237.023926  43698.253906  2237.023926
# 2024-01-06 13:22:00   43698.457031  2236.943115  43698.457031  2236.943115
# 2024-01-06 13:23:00   43693.328125  2236.354248  43693.328125  2236.354248
# 2024-01-06 13:24:00   43705.101562  2236.707031  43705.101562  2236.707031
# 2024-01-06 13:25:00   43707.925781  2237.018799  43707.925781  2237.018799
#
# comb_rsi_window                                  ...            45
# comb_rsi_period                                  ...           10T
# comb_ma_window                                   ...            90
# comb_entry_threshold                             ...            38
# comb_exit_threshold             68               ...            60
#
# comb_rsi_window
# comb_rsi_period
# comb_ma_window
# comb_entry_threshold
# comb_exit_threshold
#                           ETH-USD
# 2024-01-03 13:29:00   2224.429199
# 2024-01-03 13:30:00   2225.953125
# 2024-01-03 13:31:00   2228.655273
# 2024-01-03 13:32:00   2224.570557
# 2024-01-03 13:33:00   2223.193115
# ..                            ...
# 2024-01-06 13:21:00   2237.023926
# 2024-01-06 13:22:00   2236.943115
# 2024-01-06 13:23:00   2236.354248
# 2024-01-06 13:24:00   2236.707031
# 2024-01-06 13:25:00   2237.018799
#
# [4132 rows x 6400 columns]

# %%
pf.stats()
# Out:
# /opt/conda/envs/default/lib/python3.10/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning: Metric 'sharpe_ratio' requires frequency to be set
#   warnings.warn(warning_message)
# /opt/conda/envs/default/lib/python3.10/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning: Metric 'calmar_ratio' requires frequency to be set
#   warnings.warn(warning_message)
# /opt/conda/envs/default/lib/python3.10/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning: Metric 'omega_ratio' requires frequency to be set
#   warnings.warn(warning_message)
# /opt/conda/envs/default/lib/python3.10/site-packages/vectorbt/generic/stats_builder.py:396: UserWarning: Metric 'sortino_ratio' requires frequency to be set
#   warnings.warn(warning_message)
# /tmp/ipykernel_7578/3705677322.py:1: UserWarning: Object has multiple columns. Aggregating using <function mean at 0x7f6e6d1d5e10>. Pass column to select a single column/group.
#   pf.stats()
# Start                         2024-01-03 13:29:00
# End                           2024-01-06 13:25:00
# Period                                       4132
# Start Value                                 100.0
# End Value                              100.125802
# Total Return [%]                         0.125802
# Benchmark Return [%]                     1.669209
# Max Gross Exposure [%]                      73.75
# Total Fees Paid                               0.0
# Max Drawdown [%]                         2.692959
# Max Drawdown Duration                 1640.676907
# Total Trades                             2.388281
# Total Closed Trades                      1.684531
# Total Open Trades                         0.70375
# Open Trade PnL                          -0.213694
# Win Rate [%]                            53.240158
# Best Trade [%]                           0.705513
# Worst Trade [%]                         -0.183712
# Avg Winning Trade [%]                    0.714849
# Avg Losing Trade [%]                    -0.282496
# Avg Winning Trade Duration             447.313311
# Avg Losing Trade Duration              569.382001
# Profit Factor                                 inf
# Expectancy                                0.27929
# Name: agg_func_mean, dtype: object

# %%
pd.DataFrame(pf.final_value()).sort_values(
    "final_value", ascending=False
).head()
# Out:
#                                                                                                  final_value
# comb_rsi_window comb_rsi_period comb_ma_window comb_entry_threshold comb_exit_threshold
# 30              10T             50             32                   64                  BTC-USD   103.710951
# 40              10T             20             34                   60                  BTC-USD   103.710951
#                                                30                   64                  BTC-USD   103.710951
# 35              10T             50             34                   66                  BTC-USD   103.710951
# 30              10T             40             32                   60                  BTC-USD   103.710951

# %%
total_return = pf.total_return()
index_str = str(total_return.idxmax())
max_return = total_return.max()
print(f"{index_str}: {max_return}")
# total_return.index.names
# print(total_return)
# for pair in PAIRS:
#     currency_returns = total_return[total_return.index.isin([pair])]
#     indices = currency_returns.idxmax()
#     value = currency_returns.max()
#     print(f"{pair} {str(indices)}: {value}")
# Out:
# (30, '10T', 20, 30, 60, 'BTC-USD'): 0.03710951052638876
