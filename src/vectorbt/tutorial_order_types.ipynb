# %%
import vectorbt as vbt
import pandas as pd
import numpy as np
from IPython.display import HTML
from src.config import ASSETS_PATH

pd.set_option("display.max_rows", None)
HTML(f"{ASSETS_PATH}/vscode-jupyter-styles.html")
# Out:
# <style>
#   .cell-output-ipywidget-background {
#     background-color: transparent !important;
#   }
#
#   .jp-OutputArea-output {
#     background-color: transparent;
#   }
#
# </style>

# %%
import sys

if sys.modules.get("order_types") is not None:
    del sys.modules["order_types"]
from order_types import OrderTypes

PAIRS = ["BTC"]
o = OrderTypes("USD", PAIRS, "order_types.json")
prices = o.get_data(1, "1m", use_cache=False)
o.create_indicator()
o.run(
    rsi_window=np.array([10], dtype=int),
    entry_threshold=np.array([30], dtype=int),
    exit_threshold=np.array([80], dtype=int),
)
pf = o.create_portfolio(
    entries=o.entries,
    exits=o.exits,
    short_entries=o.exits,
    short_exits=o.entries,
    sl_stop=0.001,
    # tp_stop=0.001,
    # sl_trail=0.001,
    # upon_stop_exit=vbt.portfolio.enums.StopExitMode.Reverse,
)

print(pf.total_return() * 100)
pf.plot()
# Out:
# Pulling new data to order_types.json…
# 5.629610154891381
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1306b501-e39e-483d-a405-3ded3dd7b654',
#               'x': array([datetime.datetime(2024, 1, 7, 17, 17, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 1, 7, 17, 18, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 1, 7, 17, 19, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 1, 8, 17, 11, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 1, 8, 17, 12, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 1, 8, 17, 13, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
# ...
